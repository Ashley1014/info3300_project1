# %%
import pandas as pd
import numpy as np

df = pd.read_csv("datanet.csv")

# %%
df.head()
# Out:
#   Continent   Sub-Continent  Country  \
# 0    Africa  Eastern Africa  Burundi
# 1    Africa  Eastern Africa  Burundi
# 2    Africa  Eastern Africa  Burundi
# 3    Africa  Eastern Africa  Burundi
# 4    Africa  Eastern Africa  Comoros
#
#    Percentage distribution of women aged 15-49  (per country)  \
# 0                                           0.650838
# 1                                           0.113709
# 2                                           0.024347
# 3                                           0.211106
# 4                                           0.666126
#
#              Pregnancy intention Contraceptive availability  \
# 0  Not wanting to avoid pregancy             Not applicable
# 1     Wanting to avoid pregnancy                   Met need
# 2     Wanting to avoid pregnancy                 Unmet need
# 3     Wanting to avoid pregnancy                 Unmet need
# 4  Not wanting to avoid pregancy             Not applicable
#
#         Contraceptive method
# 0             Not applicable
# 1       Using modern methods
# 2  Using traditional methods
# 3            Using no method
# 4             Not applicable

# %%
df.columns = ['continent', 'sub-cont', 'country', 'percent', 'preg_intention', 'contraceptive_ability', 'contraceptive_method']
df
# Out:
#                            continent        sub-cont    country   percent  \
# 0                             Africa  Eastern Africa    Burundi  0.650838
# 1                             Africa  Eastern Africa    Burundi  0.113709
# 2                             Africa  Eastern Africa    Burundi  0.024347
# 3                             Africa  Eastern Africa    Burundi  0.211106
# 4                             Africa  Eastern Africa    Comoros  0.666126
# ..                               ...             ...        ...       ...
# 587  Latin America and the Caribbean   South America    Uruguay  0.089171
# 588  Latin America and the Caribbean   South America  Venezuela  0.319888
# 589  Latin America and the Caribbean   South America  Venezuela  0.540280
# 590  Latin America and the Caribbean   South America  Venezuela  0.046002
# 591  Latin America and the Caribbean   South America  Venezuela  0.093829
#
#                     preg_intention contraceptive_ability  \
# 0    Not wanting to avoid pregancy        Not applicable
# 1       Wanting to avoid pregnancy              Met need
# 2       Wanting to avoid pregnancy            Unmet need
# 3       Wanting to avoid pregnancy            Unmet need
# 4    Not wanting to avoid pregancy        Not applicable
# ..                             ...                   ...
# 587     Wanting to avoid pregnancy            Unmet need
# 588  Not wanting to avoid pregancy        Not applicable
# 589     Wanting to avoid pregnancy              Met need
# 590     Wanting to avoid pregnancy            Unmet need
# 591     Wanting to avoid pregnancy            Unmet need
#
#           contraceptive_method
# 0               Not applicable
# 1         Using modern methods
# 2    Using traditional methods
# 3              Using no method
# 4               Not applicable
# ..                         ...
# 587            Using no method
# 588             Not applicable
# 589       Using modern methods
# 590  Using traditional methods
# 591            Using no method
#
# [592 rows x 7 columns]

# %%
df = df.drop(columns = ['preg_intention', 'contraceptive_ability'])
df
# Out:
#                            continent        sub-cont    country   percent  \
# 0                             Africa  Eastern Africa    Burundi  0.650838
# 1                             Africa  Eastern Africa    Burundi  0.113709
# 2                             Africa  Eastern Africa    Burundi  0.024347
# 3                             Africa  Eastern Africa    Burundi  0.211106
# 4                             Africa  Eastern Africa    Comoros  0.666126
# ..                               ...             ...        ...       ...
# 587  Latin America and the Caribbean   South America    Uruguay  0.089171
# 588  Latin America and the Caribbean   South America  Venezuela  0.319888
# 589  Latin America and the Caribbean   South America  Venezuela  0.540280
# 590  Latin America and the Caribbean   South America  Venezuela  0.046002
# 591  Latin America and the Caribbean   South America  Venezuela  0.093829
#
#           contraceptive_method
# 0               Not applicable
# 1         Using modern methods
# 2    Using traditional methods
# 3              Using no method
# 4               Not applicable
# ..                         ...
# 587            Using no method
# 588             Not applicable
# 589       Using modern methods
# 590  Using traditional methods
# 591            Using no method
#
# [592 rows x 5 columns]

# %%
df = df.astype({"percent": str})
df.dtypes
# Out:
# continent               object
# sub-cont                object
# country                 object
# percent                 object
# contraceptive_method    object
# dtype: object

# %%
# combine based on Order_Number
df_ = df.groupby(["continent","sub-cont", "country"]).agg({'percent':'|'.join,'contraceptive_method':'|'.join}).reset_index()
df_
# Out:
#     continent        sub-cont                         country  \
# 0      Africa  Eastern Africa                         Burundi
# 1      Africa  Eastern Africa                         Comoros
# 2      Africa  Eastern Africa                        Djibouti
# 3      Africa  Eastern Africa                         Eritrea
# 4      Africa  Eastern Africa                        Ethiopia
# ..        ...             ...                             ...
# 143   Oceania      Micronesia  Federated States of Micronesia
# 144   Oceania      Micronesia                            Guam
# 145   Oceania       Polynesia                French Polynesia
# 146   Oceania       Polynesia                           Samoa
# 147   Oceania       Polynesia                           Tonga
#
#                                                percent  \
# 0    0.650837821966518|0.113709303450489|0.02434677...
# 1    0.666126226720115|0.0950685632979558|0.0381693...
# 2    0.657093774664966|0.161502279869941|0.01147116...
# 3    0.703098353744449|0.058524804703874|0.01067213...
# 4    0.62460198593714|0.233723052550546|0.002815501...
# ..                                                 ...
# 143  0.682407459662842|0.150298213307114|0.05002416...
# 144  0.680578170479635|0.153574928451917|0.05028029...
# 145  0.760404336758419|0.124864945647091|0.04185118...
# 146  0.643755599290189|0.138983464781942|0.01528682...
# 147  0.661236843684458|0.173123413960892|0.04011988...
#
#                                   contraceptive_method
# 0    Not applicable|Using modern methods|Using trad...
# 1    Not applicable|Using modern methods|Using trad...
# 2    Not applicable|Using modern methods|Using trad...
# 3    Not applicable|Using modern methods|Using trad...
# 4    Not applicable|Using modern methods|Using trad...
# ..                                                 ...
# 143  Not applicable|Using modern methods|Using trad...
# 144  Not applicable|Using modern methods|Using trad...
# 145  Not applicable|Using modern methods|Using trad...
# 146  Not applicable|Using modern methods|Using trad...
# 147  Not applicable|Using modern methods|Using trad...
#
# [148 rows x 5 columns]

# %%
# split and expand
df_1 = df_['percent'].str.split('|', expand=True).add_prefix('per_')
df_2 = df_['contraceptive_method'].str.split('|', expand=True).add_prefix('method_')

# %%
df_1
# Out:
#                  per_0               per_1                per_2  \
# 0    0.650837821966518   0.113709303450489   0.0243467777792835
# 1    0.666126226720115  0.0950685632979558   0.0381693114384136
# 2    0.657093774664966   0.161502279869941   0.0114711675244917
# 3    0.703098353744449   0.058524804703874   0.0106721344220529
# 4     0.62460198593714   0.233723052550546  0.00281550186099756
# ..                 ...                 ...                  ...
# 143  0.682407459662842   0.150298213307114     0.05002416486164
# 144  0.680578170479635   0.153574928451917   0.0502802916867374
# 145  0.760404336758419   0.124864945647091   0.0418511882375809
# 146  0.643755599290189   0.138983464781942   0.0152868228107482
# 147  0.661236843684458   0.173123413960892   0.0401198832367225
#
#                   per_3
# 0     0.211106096803709
# 1     0.200635898543516
# 2     0.169932777940601
# 3     0.227704707129624
# 4     0.138859459651317
# ..                  ...
# 143   0.117270162168405
# 144    0.11556660938171
# 145  0.0728795293569093
# 146   0.201949764898543
# 147   0.125463188122968
#
# [148 rows x 4 columns]

# %%
df_2
# Out:
#            method_0              method_1                   method_2  \
# 0    Not applicable  Using modern methods  Using traditional methods
# 1    Not applicable  Using modern methods  Using traditional methods
# 2    Not applicable  Using modern methods  Using traditional methods
# 3    Not applicable  Using modern methods  Using traditional methods
# 4    Not applicable  Using modern methods  Using traditional methods
# ..              ...                   ...                        ...
# 143  Not applicable  Using modern methods  Using traditional methods
# 144  Not applicable  Using modern methods  Using traditional methods
# 145  Not applicable  Using modern methods  Using traditional methods
# 146  Not applicable  Using modern methods  Using traditional methods
# 147  Not applicable  Using modern methods  Using traditional methods
#
#             method_3
# 0    Using no method
# 1    Using no method
# 2    Using no method
# 3    Using no method
# 4    Using no method
# ..               ...
# 143  Using no method
# 144  Using no method
# 145  Using no method
# 146  Using no method
# 147  Using no method
#
# [148 rows x 4 columns]

# %%
df_ = pd.concat([df_, df_1, df_2], axis=1).drop(['percent', 'contraceptive_method'], axis=1)

# %%
df_ = df_.drop(columns = ['method_0', 'method_1', 'method_2', 'method_3'])
df_.columns = ['continent', 'sub-cont', 'country', 'per_na', 'per_modern', 'per_traditional', 'per_nomethod']

# %%
df_.to_json('data.json', orient='records')

# %%
df_.columns
# Out:
# Index(['continent', 'sub-cont', 'country', 'per_na', 'per_modern',
#        'per_traditional', 'per_nomethod'],
#       dtype='object')

# %%
# numColumns = ['per_na', 'per_modern', 'per_traditional', 'per_nomethod']

# for x in numColumns:
#     df_[x] = df_[x].astype(float)

# %%
ax1 = df_.plot.scatter(x='per_modern', y='per_na',c='pink')

# %%
import seaborn as sns
sns.scatterplot(data=df_, x="per_modern", y="per_na", hue = "continent")
# Out:
# <AxesSubplot:xlabel='per_modern', ylabel='per_na'>

# %%
sns.regplot(data=df_, x="per_modern", y="per_na")
# Out:
# <AxesSubplot:xlabel='per_modern', ylabel='per_na'>
